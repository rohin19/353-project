# %%
from nba_api.stats.static import teams

nba_teams = teams.get_teams()

# Select the dictionary for the Pacers, which contains their team ID
pacers = [team for team in nba_teams if team["abbreviation"] == "IND"][0]
pacers_id = pacers["id"]
print(f"pacers_id: {pacers_id}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Get the Pacers team_id
# ----> 2 from nba_api.stats.static import teams
#       4 nba_teams = teams.get_teams()
#       6 # Select the dictionary for the Pacers, which contains their team ID
#
# ModuleNotFoundError: No module named 'nba_api'

# %%
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season, SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(
    team_id_nullable=pacers_id,
    season_nullable=Season.default,
    season_type_nullable=SeasonType.regular,
)

games_dict = gamefinder.get_normalized_dict()
games = games_dict["LeagueGameFinderResults"]
game = games[0]
game_id = game["GAME_ID"]
game_matchup = game["MATCHUP"]

print(
    f"Searching through {len(games)} game(s) for the game_id of {game_id} where {game_matchup}"
)
